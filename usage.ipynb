# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python '/content/drive/MyDrive/Colab/COMP9444/bert_siamese_2branch.py'
# Out:
# 2025-04-09 17:41:16.181488: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744220476.202235   34237 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744220476.208605   34237 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-09 17:41:16.230129: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# cuda:0
# {'train': <torch.utils.data.dataloader.DataLoader object at 0x7edc80764b90>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x7edc8fc4a1d0>, 'test': <torch.utils.data.dataloader.DataLoader object at 0x7edc80667c10>}
# {'train': 10240, 'val': 1284, 'test': 1267}
# starting
# Epoch 1/100
# ----------
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# train total loss: 1.7253
# train sentiment_acc: 0.2936
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2074    0.0268    0.0475      1676
#            1     0.3710    0.4506    0.4069      1962
#            2     0.2488    0.3798    0.3007      2114
#            3     0.2096    0.0659    0.1003      1654
#            4     0.2993    0.5840    0.3957      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.2936     10240
#    macro avg     0.2227    0.2512    0.2085     10240
# weighted avg     0.2485    0.2936    0.2411     10240
#
# 🔍 Confusion Matrix:
# [[  45  487  640   80  424    0]
#  [  33  884  652   62  331    0]
#  [  57  584  803  103  567    0]
#  [  31  202  506  109  806    0]
#  [  40  196  482  112 1165    0]
#  [  11   30  144   54  600    0]]
# val total loss: 1.6913
# val sentiment_acc: 0.3232
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000       169
#            1     0.6777    0.3267    0.4409       251
#            2     0.2622    0.6089    0.3665       248
#            3     0.0000    0.0000    0.0000       237
#            4     0.3101    0.6920    0.4282       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3232      1284
#    macro avg     0.2083    0.2713    0.2059      1284
# weighted avg     0.2466    0.3232    0.2447      1284
#
# 🔍 Confusion Matrix:
# [[  0  14 100   0  55   0]
#  [  0  82 128   0  41   0]
#  [  0  20 151   0  77   0]
#  [  0   3  93   0 141   0]
#  [  0   2  79   0 182   0]
#  [  0   0  25   0  91   0]]
# Saving with accuracy of 0.32320872274143303 improved over previous 0
# Time taken for epoch1 is 7.77624895175298 minutes
#
# Epoch 2/100
# ----------
# train total loss: 1.7068
# train sentiment_acc: 0.3184
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2356    0.0853    0.1253      1676
#            1     0.5725    0.3180    0.4089      1962
#            2     0.2683    0.5998    0.3708      2114
#            3     0.2143    0.0181    0.0334      1654
#            4     0.3250    0.5990    0.4214      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.3184     10240
#    macro avg     0.2693    0.2701    0.2266     10240
# weighted avg     0.3016    0.3184    0.2629     10240
#
# 🔍 Confusion Matrix:
# [[ 143  203  955   20  355    0]
#  [ 114  624  987   12  225    0]
#  [ 179  184 1268   25  458    0]
#  [  74   41  689   30  820    0]
#  [  81   34  647   38 1195    0]
#  [  16    4  180   15  624    0]]
# val total loss: 1.6986
# val sentiment_acc: 0.3294
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000       169
#            1     0.6972    0.3028    0.4222       251
#            2     0.2869    0.5726    0.3822       248
#            3     0.0000    0.0000    0.0000       237
#            4     0.3015    0.7795    0.4348       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3294      1284
#    macro avg     0.2143    0.2758    0.2065      1284
# weighted avg     0.2535    0.3294    0.2454      1284
#
# 🔍 Confusion Matrix:
# [[  0  13  91   0  65   0]
#  [  0  76 119   0  56   0]
#  [  0  16 142   0  90   0]
#  [  0   2  70   0 165   0]
#  [  0   2  56   0 205   0]
#  [  0   0  17   0  99   0]]
# Saving with accuracy of 0.3294392523364486 improved over previous 0.32320872274143303
# Time taken for epoch2 is 7.81554141441981 minutes
#
# Epoch 3/100
# ----------
# train total loss: 1.6940
# train sentiment_acc: 0.3250
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2539    0.0770    0.1181      1676
#            1     0.6161    0.3394    0.4377      1962
#            2     0.2718    0.6145    0.3768      2114
#            3     0.0000    0.0000    0.0000      1654
#            4     0.3188    0.6185    0.4207      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.3250     10240
#    macro avg     0.2434    0.2749    0.2256     10240
# weighted avg     0.2778    0.3250    0.2630     10240
#
# 🔍 Confusion Matrix:
# [[ 129  160 1022    0  365    0]
#  [ 110  666  955    0  231    0]
#  [ 155  176 1299    0  484    0]
#  [  51   38  665    0  900    0]
#  [  57   37  667    0 1234    0]
#  [   6    4  172    0  657    0]]
# val total loss: 1.6918
# val sentiment_acc: 0.3341
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000       169
#            1     0.6842    0.3108    0.4274       251
#            2     0.2718    0.7903    0.4045       248
#            3     0.0000    0.0000    0.0000       237
#            4     0.3452    0.5894    0.4354       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3341      1284
#    macro avg     0.2169    0.2817    0.2112      1284
# weighted avg     0.2570    0.3341    0.2509      1284
#
# 🔍 Confusion Matrix:
# [[  0  14 112   0  43   0]
#  [  0  78 148   0  25   0]
#  [  0  18 196   0  34   0]
#  [  0   2 126   0 109   0]
#  [  0   2 106   0 155   0]
#  [  0   0  33   0  83   0]]
# Saving with accuracy of 0.3341121495327103 improved over previous 0.3294392523364486
# Time taken for epoch3 is 7.813215482234955 minutes
#
# Epoch 4/100
# ----------
# train total loss: 1.6888
# train sentiment_acc: 0.3271
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2585    0.1175    0.1616      1676
#            1     0.6117    0.3308    0.4294      1962
#            2     0.2732    0.6287    0.3809      2114
#            3     0.1875    0.0181    0.0331      1654
#            4     0.3375    0.5739    0.4250      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.3271     10240
#    macro avg     0.2781    0.2782    0.2383     10240
# weighted avg     0.3120    0.3271    0.2755     10240
#
# 🔍 Confusion Matrix:
# [[ 197  170  982   24  303    0]
#  [ 166  649  956   21  170    0]
#  [ 205  170 1329   31  379    0]
#  [  90   34  721   30  779    0]
#  [  88   34  687   41 1145    0]
#  [  16    4  189   13  617    0]]
# val total loss: 1.6794
# val sentiment_acc: 0.3357
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000       169
#            1     0.6885    0.3347    0.4504       251
#            2     0.2622    0.8427    0.4000       248
#            3     0.0000    0.0000    0.0000       237
#            4     0.3781    0.5247    0.4395       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3357      1284
#    macro avg     0.2215    0.2837    0.2150      1284
# weighted avg     0.2627    0.3357    0.2553      1284
#
# 🔍 Confusion Matrix:
# [[  0  14 117   0  38   0]
#  [  0  84 153   0  14   0]
#  [  0  19 209   0  20   0]
#  [  0   3 157   0  77   0]
#  [  0   2 123   0 138   0]
#  [  0   0  38   0  78   0]]
# Saving with accuracy of 0.3356697819314642 improved over previous 0.3341121495327103
# Time taken for epoch4 is 7.811231553554535 minutes
#
# Epoch 5/100
# ----------
# train total loss: 1.6783
# train sentiment_acc: 0.3394
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2582    0.1402    0.1817      1676
#            1     0.6158    0.3252    0.4256      1962
#            2     0.2899    0.5875    0.3882      2114
#            3     0.2584    0.1723    0.2067      1654
#            4     0.3698    0.5388    0.4386      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.3394     10240
#    macro avg     0.2987    0.2940    0.2735     10240
# weighted avg     0.3339    0.3394    0.3103     10240
#
# 🔍 Confusion Matrix:
# [[ 235  158  881  127  275    0]
#  [ 173  638  879  134  138    0]
#  [ 231  165 1242  224  252    0]
#  [ 120   39  607  285  603    0]
#  [ 126   32  537  225 1075    0]
#  [  25    4  138  108  564    0]]
# val total loss: 1.6710
# val sentiment_acc: 0.3583
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2778    0.0592    0.0976       169
#            1     0.6885    0.3347    0.4504       251
#            2     0.2721    0.7702    0.4021       248
#            3     0.4231    0.1857    0.2581       237
#            4     0.4094    0.4981    0.4494       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3583      1284
#    macro avg     0.3451    0.3080    0.2763      1284
# weighted avg     0.3857    0.3583    0.3182      1284
#
# 🔍 Confusion Matrix:
# [[ 10  14 100  13  32   0]
#  [  5  84 144   8  10   0]
#  [  8  19 191  14  16   0]
#  [  3   3 130  44  57   0]
#  [  6   2 103  21 131   0]
#  [  4   0  34   4  74   0]]
# Saving with accuracy of 0.3582554517133956 improved over previous 0.3356697819314642
# Time taken for epoch5 is 7.806742080052694 minutes
#
# Epoch 6/100
# ----------
# train total loss: 1.6732
# train sentiment_acc: 0.3487
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2949    0.1450    0.1944      1676
#            1     0.6192    0.3323    0.4325      1962
#            2     0.2952    0.6026    0.3963      2114
#            3     0.2857    0.2019    0.2366      1654
#            4     0.3711    0.5353    0.4383      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.3487     10240
#    macro avg     0.3110    0.3029    0.2830     10240
# weighted avg     0.3463    0.3487    0.3201     10240
#
# 🔍 Confusion Matrix:
# [[ 243  157  871  128  277    0]
#  [ 150  652  883  140  137    0]
#  [ 196  165 1274  236  243    0]
#  [  92   41  611  334  576    0]
#  [ 121   33  540  233 1068    0]
#  [  22    5  137   98  577    0]]
# val total loss: 1.6696
# val sentiment_acc: 0.3621
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2319    0.0947    0.1345       169
#            1     0.6960    0.3466    0.4628       251
#            2     0.2767    0.7097    0.3982       248
#            3     0.4174    0.2025    0.2727       237
#            4     0.4071    0.5247    0.4585       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3621      1284
#    macro avg     0.3382    0.3130    0.2878      1284
# weighted avg     0.3804    0.3621    0.3293      1284
#
# 🔍 Confusion Matrix:
# [[ 16  14  92  12  35   0]
#  [ 12  87 129   9  14   0]
#  [ 18  19 176  16  19   0]
#  [ 11   3 115  48  60   0]
#  [  8   2  94  21 138   0]
#  [  4   0  30   9  73   0]]
# Saving with accuracy of 0.3621495327102804 improved over previous 0.3582554517133956
# Time taken for epoch6 is 7.804580310980479 minutes
#
# Epoch 7/100
# ----------
# train total loss: 1.6689
# train sentiment_acc: 0.3579
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2931    0.1838    0.2259      1676
#            1     0.6240    0.3257    0.4280      1962
#            2     0.3050    0.5918    0.4025      2114
#            3     0.3126    0.2122    0.2528      1654
#            4     0.3796    0.5594    0.4523      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.3579     10240
#    macro avg     0.3190    0.3121    0.2936     10240
# weighted avg     0.3549    0.3579    0.3310     10240
#
# 🔍 Confusion Matrix:
# [[ 308  157  805  136  270    0]
#  [ 201  639  860  111  151    0]
#  [ 240  159 1251  204  260    0]
#  [ 134   34  566  351  569    0]
#  [ 142   30  500  207 1116    0]
#  [  26    5  120  114  574    0]]
# val total loss: 1.6686
# val sentiment_acc: 0.3590
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.1875    0.1065    0.1358       169
#            1     0.6942    0.3347    0.4516       251
#            2     0.2899    0.6815    0.4067       248
#            3     0.3526    0.2321    0.2799       237
#            4     0.4116    0.5133    0.4569       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3590      1284
#    macro avg     0.3226    0.3113    0.2885      1284
# weighted avg     0.3658    0.3590    0.3300      1284
#
# 🔍 Confusion Matrix:
# [[ 18  14  86  20  31   0]
#  [ 21  84 118  15  13   0]
#  [ 22  18 169  22  17   0]
#  [ 15   3 105  55  59   0]
#  [ 14   2  81  31 135   0]
#  [  6   0  24  13  73   0]]
# Time taken for epoch7 is 7.7916947364807125 minutes
#
# Epoch 8/100
# ----------
# train total loss: 1.6710
# train sentiment_acc: 0.3524
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2742    0.1605    0.2025      1676
#            1     0.6236    0.3226    0.4253      1962
#            2     0.3001    0.5672    0.3925      2114
#            3     0.3096    0.2388    0.2696      1654
#            4     0.3745    0.5579    0.4482      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.3524     10240
#    macro avg     0.3137    0.3078    0.2897     10240
# weighted avg     0.3493    0.3524    0.3265     10240
#
# 🔍 Confusion Matrix:
# [[ 269  157  819  132  299    0]
#  [ 181  633  850  123  175    0]
#  [ 236  160 1199  262  257    0]
#  [ 125   32  546  395  556    0]
#  [ 147   31  458  246 1113    0]
#  [  23    2  124  118  572    0]]
# val total loss: 1.6682
# val sentiment_acc: 0.3583
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.1827    0.1124    0.1392       169
#            1     0.6911    0.3386    0.4545       251
#            2     0.2890    0.6653    0.4029       248
#            3     0.3600    0.2278    0.2791       237
#            4     0.4077    0.5209    0.4574       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3583      1284
#    macro avg     0.3217    0.3109    0.2889      1284
# weighted avg     0.3649    0.3583    0.3302      1284
#
# 🔍 Confusion Matrix:
# [[ 19  14  85  19  32   0]
#  [ 24  85 114  14  14   0]
#  [ 25  19 165  22  17   0]
#  [ 15   3 103  54  62   0]
#  [ 15   2  80  29 137   0]
#  [  6   0  24  12  74   0]]
# Time taken for epoch8 is 7.7901121536890665 minutes
#
# Epoch 9/100
# ----------
# train total loss: 1.6693
# train sentiment_acc: 0.3579
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.2734    0.1868    0.2219      1676
#            1     0.6216    0.3308    0.4318      1962
#            2     0.3099    0.5695    0.4014      2114
#            3     0.3133    0.2267    0.2631      1654
#            4     0.3786    0.5634    0.4529      1995
#            5     0.0000    0.0000    0.0000       839
#
#     accuracy                         0.3579     10240
#    macro avg     0.3161    0.3129    0.2952     10240
# weighted avg     0.3522    0.3579    0.3326     10240
#
# 🔍 Confusion Matrix:
# [[ 313  164  764  127  308    0]
#  [ 229  649  812  115  157    0]
#  [ 262  163 1204  233  252    0]
#  [ 146   38  537  375  558    0]
#  [ 164   25  453  229 1124    0]
#  [  31    5  115  118  570    0]]
# val total loss: 1.6682
# val sentiment_acc: 0.3583
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.1827    0.1124    0.1392       169
#            1     0.6911    0.3386    0.4545       251
#            2     0.2877    0.6613    0.4010       248
#            3     0.3618    0.2321    0.2828       237
#            4     0.4090    0.5209    0.4582       263
#            5     0.0000    0.0000    0.0000       116
#
#     accuracy                         0.3583      1284
#    macro avg     0.3220    0.3109    0.2893      1284
# weighted avg     0.3653    0.3583    0.3307      1284
#
# 🔍 Confusion Matrix:
# [[ 19  14  85  19  32   0]
#  [ 24  85 114  14  14   0]
#  [ 25  19 164  23  17   0]
#  [ 15   3 103  55  61   0]
#  [ 15   2  80  29 137   0]
#  [  6   0  24  12  74   0]]
# Time taken for epoch9 is 7.789307951927185 minutes
# ⛔ Early stopping at epoch 9
# Training complete in 70m 12s
# Best val Acc: 0.362150
#
# 🧪 Evaluation Results:
# 📉 Average Loss: 1.6797
# ✅ Accuracy: 33.15%
#
# 📊 Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.1818    0.0769    0.1081       208
#            1     0.5702    0.2697    0.3662       241
#            2     0.2746    0.6528    0.3866       265
#            3     0.3154    0.1934    0.2398       212
#            4     0.4098    0.5020    0.4513       249
#            5     0.0000    0.0000    0.0000        92
#
#     accuracy                         0.3315      1267
#    macro avg     0.2920    0.2825    0.2587      1267
# weighted avg     0.3291    0.3315    0.2971      1267
#
# 🔍 Confusion Matrix:
# [[ 16  26 125  15  26   0]
#  [ 19  65 137   7  13   0]
#  [ 30  17 173  26  19   0]
#  [  6   3 105  41  57   0]
#  [ 15   3  77  29 125   0]
#  [  2   0  13  12  65   0]]
